# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files("data/song_data")

# %%
filepath = 'data/song_data/A/B/C/TRABCRU128F423F449.json'

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#             artist_id  artist_latitude artist_location  artist_longitude  \
# 0  AR8IEZO1187B99055E              NaN                               NaN
#
#     artist_name   duration  num_songs             song_id          title  year
# 0  Marc Shaiman  149.86404          1  SOINLJW12A8C13314C  City Slickers  2008

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = list(df[['song_id', 'title','artist_id', 'year', 'duration']].values)[0]
song_data
# Out:
# array(['SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008,
#        149.86404], dtype=object)

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = list(df[['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']].values)[0]
artist_data
# Out:
# array(['AR8IEZO1187B99055E', 'Marc Shaiman', '', nan, nan], dtype=object)

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#             artist_id  artist_latitude artist_location  artist_longitude  \
# 0  AR8IEZO1187B99055E              NaN                               NaN
#
#     artist_name   duration  num_songs             song_id          title  year
# 0  Marc Shaiman  149.86404          1  SOINLJW12A8C13314C  City Slickers  2008

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files(filepath)
print(log_files)
# Out:
# []

# %%
filepath = "data/log_data/2018/11/2018-11-30-events.json"

# %%
df = pd.read_json(filepath, lines=True)

df.head()
# Out:
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df.loc[df["page"] == 'NextSong']
df.head()
# Out:
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %%
t = df
t['time_data'] = pd.to_datetime(df['ts'], unit='ms')
t['timestamp'] = t['time_data']
t['hour'] = t['time_data'].dt.hour
t['day'] = t['time_data'].dt.day
t['week'] = t['time_data'].dt.week
t['month'] = t['time_data'].dt.month
t['year'] = t['time_data'].dt.year
t['weekday'] = t['time_data'].dt.weekday
t = t[['timestamp', 'hour', 'day', 'week', 'month', 'year', 'weekday']]
t.head()
# (start_time timestamp, hour int, day int, week int, month int, year int, weekday int)
# Out:
#                 timestamp  hour  day  week  month  year  weekday
# 0 2018-11-30 00:22:07.796     0   30    48     11  2018        4
# 1 2018-11-30 01:08:41.796     1   30    48     11  2018        4
# 2 2018-11-30 01:12:48.796     1   30    48     11  2018        4
# 3 2018-11-30 01:17:05.796     1   30    48     11  2018        4
# 4 2018-11-30 01:20:56.796     1   30    48     11  2018        4

# %%
time_data = (['timestamp', 'hour', 'day', 'week', 'month', 'year', 'weekday'])
column_labels = ()

# %%
time_df = t[['timestamp', 'hour', 'day', 'week', 'month', 'year', 'weekday']]
time_df.head()
# Out:
#                 timestamp  hour  day  week  month  year  weekday
# 0 2018-11-30 00:22:07.796     0   30    48     11  2018        4
# 1 2018-11-30 01:08:41.796     1   30    48     11  2018        4
# 2 2018-11-30 01:12:48.796     1   30    48     11  2018        4
# 3 2018-11-30 01:17:05.796     1   30    48     11  2018        4
# 4 2018-11-30 01:20:56.796     1   30    48     11  2018        4

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = get_files("data/song_data")
df = pd.read_json(filepath, lines=True)
# df.head()
user_df = df[['userId', 'firstName', 'lastName', 'gender', 'level']]
user_df.head()
# Out:
#   userId firstName lastName gender level
# 0     91    Jayden     Bell      M  free
# 1     73     Jacob    Klein      M  paid
# 2     73     Jacob    Klein      M  paid
# 3     73     Jacob    Klein      M  paid
# 4     73     Jacob    Klein      M  paid

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
df = pd.read_json("data/log_data/2018/11/2018-11-30-events.json", lines=True)
df = df.loc[df["page"] == 'NextSong']
df['start_time'] = pd.to_datetime(df['ts'], unit='ms')
songplay_id = 1

for index, row in df.iterrows():
 
    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None
        
    aux = row[['start_time', 'userId', 'level','song','artist', 'sessionId', 'location', 'userAgent']].values
    aux[4] = artistid
    aux[3] = songid
    aux1 = [songplay_id]
    
    
#     # insert songplay record
    songplay_data = aux
    print(songplay_data)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()
    songplay_id = songplay_id+1
#     songplay_id, start_time, user_id, level, song_id, artist_id, session_id, location, user_agent
# Out:
# [Timestamp('2018-11-30 00:22:07.796000') '91' 'free' None None 829
#  'Dallas-Fort Worth-Arlington, TX'
#  'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)']
# [Timestamp('2018-11-30 01:08:41.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:12:48.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:17:05.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:20:56.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:24:32.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:28:19.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:32:00.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:38:17.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:39:53.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:44:10.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:48:36.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:50:28.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 01:55:35.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 02:01:08.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 02:05:24.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 02:10:21.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 02:15:54.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 02:19:19.796000') '73' 'paid' None None 1049
#  'Tampa-St. Petersburg-Clearwater, FL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"']
# [Timestamp('2018-11-30 03:06:30.796000') '86' 'free' None None 986
#  'La Crosse-Onalaska, WI-MN'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"']
# [Timestamp('2018-11-30 03:10:30.796000') '86' 'free' None None 986
#  'La Crosse-Onalaska, WI-MN'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"']
# [Timestamp('2018-11-30 03:13:03.796000') '86' 'free' None None 986
#  'La Crosse-Onalaska, WI-MN'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"']
# [Timestamp('2018-11-30 03:15:41.796000') '86' 'free' None None 986
#  'La Crosse-Onalaska, WI-MN'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"']
# [Timestamp('2018-11-30 03:21:09.796000') '86' 'free' None None 986
#  'La Crosse-Onalaska, WI-MN'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"']
# [Timestamp('2018-11-30 03:29:23.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 03:32:46.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 03:37:24.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 03:39:31.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 03:44:28.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 03:49:50.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 03:55:42.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 03:58:21.796000') '26' 'free' None None 1068
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:00:57.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:04:13.796000') '26' 'free' None None 1068
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:06:01.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:09:20.796000') '26' 'free' None None 1068
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:12:58.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:13:07.796000') '26' 'free' None None 1068
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:17:10.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:20:32.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:21:20.796000') '26' 'free' None None 1068
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:23:31.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:24:50.796000') '26' 'free' None None 1068
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:26:49.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:27:14.796000') '26' 'free' None None 1068
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:31:08.796000') '24' 'paid' None None 1051
#  'Lake Havasu City-Kingman, AZ'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:32:02.796000') '26' 'free' None None 1068
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:36:30.796000') '26' 'free' None None 1068
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 04:42:05.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 04:46:03.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 04:51:49.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 04:56:11.796000') '57' 'free' None None 1020
#  'San Antonio-New Braunfels, TX'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.59.10 (KHTML, like Gecko) Version/5.1.9 Safari/534.59.10"']
# [Timestamp('2018-11-30 04:57:03.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:03:06.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:06:32.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:11:09.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:12:20.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:15:12.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:16:54.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:19:35.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:20:54.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:23:34.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:24:45.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:28:28.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:29:04.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:31:25.796000') '92' 'free' None None 1006
#  'Palestine, TX'
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:31:44.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:32:47.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:36:03.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:36:45.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:39:39.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:40:31.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:43:04.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:43:56.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:46:01.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:48:56.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:50:07.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:54:19.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:57:11.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 05:58:01.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:01:40.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:04:50.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:04:55.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:07:57.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:10:18.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:12:54.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:13:23.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:14:02.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:16:35.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:18:28.796000') '30' 'paid' None None 884
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:21:31.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:26:25.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:30:35.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:33:56.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:37:14.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:40:47.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:44:27.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:48:28.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:52:31.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:54:42.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 06:58:38.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:02:23.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:08:35.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:15:24.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:18:31.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:22:12.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:24:45.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:28:29.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:29:09.796000') '74' 'free' None None 1082
#  'Youngstown-Warren-Boardman, OH-PA'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 07:31:39.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:36:23.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:38:51.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:42:37.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:47:05.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 07:49:54.796000') '49' 'paid' None None 1079
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 08:16:11.796000') '88' 'paid' None None 1075
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 08:20:12.796000') '88' 'paid' None None 1075
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 08:21:57.796000') '88' 'paid' None None 1075
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 08:26:07.796000') '88' 'paid' None None 1075
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 08:29:58.796000') '88' 'paid' None None 1075
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 08:32:43.796000') '88' 'paid' None None 1075
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 08:38:38.796000') '88' 'paid' None None 1075
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 08:46:21.796000') '88' 'paid' None None 1075
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:12:54.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:18:07.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:22:53.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:27:08.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:30:53.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:35:18.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:38:54.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:42:09.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:46:06.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:49:40.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:54:05.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 10:56:25.796000') '92' 'free' None None 1092
#  'Palestine, TX'
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 10:59:23.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:00:01.796000') '92' 'free' None None 1092
#  'Palestine, TX'
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 11:06:18.796000') '92' 'free' None None 1092
#  'Palestine, TX'
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 11:09:49.796000') '92' 'free' None None 1092
#  'Palestine, TX'
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 11:10:18.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:13:07.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:16:10.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:20:03.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:23:44.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:28:16.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:32:04.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:37:23.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:41:03.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:46:23.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 11:49:42.796000') '36' 'paid' None None 998
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 12:10:57.796000') '12' 'free' None None 1078
#  'New York-Newark-Jersey City, NY-NJ-PA'
#  'Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 12:31:18.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 12:34:47.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 12:39:36.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 12:47:53.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 12:52:50.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 12:57:05.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 12:57:53.796000') '61' 'free' None None 1064
#  'Houston-The Woodlands-Sugar Land, TX'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 13:01:42.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:05:54.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:10:16.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:13:45.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:17:25.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:20:30.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:20:44.796000') '43' 'free' None None 618
#  'San Antonio-New Braunfels, TX'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 13:27:49.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:31:28.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:34:49.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:38:42.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:41:51.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:43:40.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 13:45:20.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:48:07.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 13:48:55.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:52:37.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:52:55.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 13:56:36.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 13:57:21.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 13:57:24.796000') '50' 'free' None None 1050
#  'New Haven-Milford, CT'
#  '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 13:59:31.796000') '50' 'free' None None 1050
#  'New Haven-Milford, CT'
#  '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:00:38.796000') '26' 'free' None None 1090
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 14:01:42.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:01:43.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:03:21.796000') '50' 'free' None None 1050
#  'New Haven-Milford, CT'
#  '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:04:47.796000') '26' 'free' None None 1090
#  'San Jose-Sunnyvale-Santa Clara, CA'
#  '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 14:06:43.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:07:56.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:10:01.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:11:25.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:12:16.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:15:25.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:16:36.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:19:48.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:21:45.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:24:02.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:27:42.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:28:26.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:31:15.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:33:39.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:33:53.796000') '101' 'free' None None 1060
#  'New Orleans-Metairie, LA'
#  '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:36:07.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:37:56.796000') '101' 'free' None None 1060
#  'New Orleans-Metairie, LA'
#  '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:38:37.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:41:06.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 14:42:01.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:42:38.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 14:42:45.796000') '101' 'free' None None 1060
#  'New Orleans-Metairie, LA'
#  '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:43:50.796000') '101' 'free' None None 1060
#  'New Orleans-Metairie, LA'
#  '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:45:13.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 14:46:43.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:47:35.796000') '101' 'free' None None 1060
#  'New Orleans-Metairie, LA'
#  '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:49:37.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 14:51:37.796000') '101' 'free' None None 1060
#  'New Orleans-Metairie, LA'
#  '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:52:04.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:53:33.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 14:55:25.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:57:52.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:59:31.796000') '88' 'paid' None None 1097
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 14:59:32.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 15:01:06.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:02:42.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 15:05:47.796000') '88' 'paid' None None 1097
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:05:56.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:06:38.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 15:09:01.796000') '88' 'paid' None None 1097
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:10:07.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:11:47.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 15:12:54.796000') '36' 'paid' None None 1100
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:13:03.796000') '88' 'paid' None None 1097
#  'Sacramento--Roseville--Arden-Arcade, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:14:35.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:15:05.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 15:16:02.796000') '36' 'paid' None None 1100
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:17:07.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:18:58.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 15:21:29.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:22:09.796000') '36' 'paid' None None 1100
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:22:54.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 15:24:45.796000') '85' 'paid' None None 977
#  'Red Bluff, CA'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:25:59.796000') '36' 'paid' None None 1100
#  'Janesville-Beloit, WI'
#  '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"']
# [Timestamp('2018-11-30 15:27:25.796000') '16' 'paid' None None 1076
# ...
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 15:57:42.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 15:58:51.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 16:00:31.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:03:06.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 16:06:15.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 16:07:52.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:09:16.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 16:12:03.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:13:08.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 16:15:19.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:17:45.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 16:18:18.796000') '78' 'free' None None 1059
#  'Indianapolis-Carmel-Anderson, IN'
#  'Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 16:20:04.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:21:23.796000') '78' 'free' None None 1059
#  'Indianapolis-Carmel-Anderson, IN'
#  'Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 16:21:33.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 16:25:17.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:27:09.796000') '49' 'paid' None None 1096
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 16:31:25.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:34:12.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:35:57.796000') '33' 'free' None None 1026
#  'Eugene, OR'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 16:38:10.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:39:12.796000') '33' 'free' None None 1026
#  'Eugene, OR'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 16:41:23.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:43:28.796000') '33' 'free' None None 1026
#  'Eugene, OR'
#  '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"']
# [Timestamp('2018-11-30 16:45:28.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:49:06.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:51:42.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:55:41.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 16:59:06.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:03:03.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:07:22.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:11:16.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:16:14.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:19:28.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:19:58.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:22:01.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:24:07.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:25:36.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:28:37.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:30:27.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:31:24.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:34:27.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:35:07.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:39:08.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:39:17.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:42:58.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:44:00.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:45:41.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:47:13.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:48:55.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:49:45.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:53:44.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:54:43.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 17:57:24.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 17:58:43.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 18:03:19.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 18:04:23.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:08:07.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 18:10:01.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:13:36.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 18:14:56.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:16:20.796000') '91' 'free' None None 1085
#  'Dallas-Fort Worth-Arlington, TX'
#  'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)']
# [Timestamp('2018-11-30 18:19:03.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:19:33.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 18:21:19.796000') '91' 'free' None None 1085
#  'Dallas-Fort Worth-Arlington, TX'
#  'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)']
# [Timestamp('2018-11-30 18:21:46.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:24:05.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 18:26:12.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:28:08.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 18:29:02.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:31:34.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:32:46.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 18:35:19.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:36:25.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 18:39:22.796000') '49' 'paid' None None 1114
#  'San Francisco-Oakland-Hayward, CA'
#  'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0']
# [Timestamp('2018-11-30 18:40:05.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:44:36.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:47:58.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 18:51:24.796000') '16' 'paid' None None 1076
#  'Birmingham-Hoover, AL'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']
# [Timestamp('2018-11-30 19:54:24.796000') '5' 'free' None None 985
#  'Detroit-Warren-Dearborn, MI'
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"']

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
